# %% [markdown]
# **Advanced House Price Prediction: Feature Selecting**
#
# The main aim of this project is to predict the house price based on various features which we will discuss as we go ahead

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('X_train.csv')

# %%
dataset.head()
# Out:
#    Id  SalePrice  MSSubClass  ...  YrSold  SaleType  SaleCondition
# 0   1  12.247694    0.235294  ...    0.50  0.666667           0.75
# 1   2  12.109011    0.000000  ...    0.25  0.666667           0.75
# 2   3  12.317167    0.235294  ...    0.50  0.666667           0.75
# 3   4  11.849398    0.294118  ...    0.00  0.666667           0.00
# 4   5  12.429216    0.235294  ...    0.50  0.666667           0.75
#
# [5 rows x 81 columns]

# %%
y_train=dataset['SalePrice']

# %%
# dropping dependent feature from dataset
X_train=dataset.drop(['Id','SalePrice'],axis=1)

# %%
X_train
# Out:
#       MSSubClass  MSZoning  LotFrontage  ...  YrSold  SaleType  SaleCondition
# 0       0.235294      0.75     0.418208  ...    0.50  0.666667           0.75
# 1       0.000000      0.75     0.495064  ...    0.25  0.666667           0.75
# 2       0.235294      0.75     0.434909  ...    0.50  0.666667           0.75
# 3       0.294118      0.75     0.388581  ...    0.00  0.666667           0.00
# 4       0.235294      0.75     0.513123  ...    0.50  0.666667           0.75
# ...          ...       ...          ...  ...     ...       ...            ...
# 1455    0.235294      0.75     0.400718  ...    0.25  0.666667           0.75
# 1456    0.000000      0.75     0.517503  ...    1.00  0.666667           0.75
# 1457    0.294118      0.75     0.423859  ...    1.00  0.666667           0.75
# 1458    0.000000      0.75     0.434909  ...    1.00  0.666667           0.75
# 1459    0.000000      0.75     0.471175  ...    0.50  0.666667           0.75
#
# [1460 rows x 79 columns]

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
# Apply Feature Selection
# first, I specify the Lasso Regression model, and I
# select a suitable alpha (equivalent of penalty).
# The bigger the alpha the less features that will be selected.

# Then I use the selectFromModel object from sklearn, which
# will select the features which coefficients are non-zero

feature_sel_model=SelectFromModel(Lasso(alpha=0.01 , random_state=0))
feature_sel_model.fit(X_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.01, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
feature_sel_model.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#         True, False, False, False, False, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
select_feature=X_train.columns[(feature_sel_model.get_support())]
print('total feature',X_train.shape[1])
print('selected feature',len(select_feature))
select_feature
# Out:
# total feature 79
# selected feature 13
# Index(['Neighborhood', 'OverallQual', 'YearRemodAdd', 'RoofStyle',
#        'BsmtExposure', 'CentralAir', 'GrLivArea', 'KitchenQual', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars'],
#       dtype='object')

# %%
X_train=X_train[select_feature]
X_train
# Out:
#       Neighborhood  OverallQual  ...  GarageFinish  GarageCars
# 0         0.636364     0.666667  ...      0.666667        0.50
# 1         0.500000     0.555556  ...      0.666667        0.50
# 2         0.636364     0.666667  ...      0.666667        0.50
# 3         0.727273     0.666667  ...      0.333333        0.75
# 4         1.000000     0.777778  ...      0.666667        0.75
# ...            ...          ...  ...           ...         ...
# 1455      0.590909     0.555556  ...      0.666667        0.50
# 1456      0.545455     0.555556  ...      0.333333        0.50
# 1457      0.727273     0.666667  ...      0.666667        0.25
# 1458      0.363636     0.444444  ...      0.333333        0.25
# 1459      0.227273     0.444444  ...      1.000000        0.25
#
# [1460 rows x 13 columns]
